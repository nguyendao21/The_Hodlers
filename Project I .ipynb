# %%
import sys 
import fire
import csv
import questionary
import pandas as pd 
from pathlib import Path

import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
#Read in the CSV file called "TRX_USD.csv" using the path module. 
trx_path = Path('../PROJECT_I_dev/csv_files_crypto/TRX_USD.csv')

#Read trx csv into pandas dataframe, indexing date.
trx_df = pd.read_csv(
        trx_path, index_col='Date', infer_datetime_format=True, parse_dates=True
)
trx_df.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2020-04-15  0.012417  0.012599  0.012209  0.012225   0.012225  1227074918
# 2020-04-16  0.012218  0.013110  0.012033  0.013042   0.013042  1483226074
# 2020-04-17  0.013040  0.013119  0.012822  0.013004   0.013004  1294903478
# 2020-04-18  0.013006  0.013445  0.012988  0.013369   0.013369  1358911558
# 2020-04-19  0.013373  0.013430  0.013020  0.013032   0.013032  1297116920

# %%
#Verify 'close' data-type as "float."
trx_df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Filter out 'close' price into a sliced dataframe. 
trx_sliced = trx_df.iloc[:,[3]]

# %%
#Rename 'close' price to 'TRX/USD' in a new dataframe.
trx_new = trx_sliced.rename(columns={"Close":'TRX/USD'})

#Review the top 5 results of dataframe. 
trx_new.head()
# Out:
#              TRX/USD
# Date
# 2020-04-15  0.012225
# 2020-04-16  0.013042
# 2020-04-17  0.013004
# 2020-04-18  0.013369
# 2020-04-19  0.013032

# %%
#Read in the CSV file called "BTC_USD.csv" using the path module.
btc_path = Path('../PROJECT_I_dev/csv_files_crypto/BTC_USD.csv')

#Read btc csv into pandas dataframe, indexing date.
btc_df = pd.read_csv(
        btc_path, index_col='Date', infer_datetime_format=True, parse_dates=True
)

# %%
#Verify 'close' data-type as "float." 
btc_df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Filter out 'close' price into sliced dataframe. 
btc_sliced = btc_df.iloc[:,[3]]

# %%
#Rename 'close' price to 'BTC/USD' in a new dataframe.
btc_new = btc_sliced.rename(columns={"Close":"BTC/USD"})

#Display the top 5 results.
btc_new.head()
# Out:
#                 BTC/USD
# Date
# 2020-04-15  6642.109863
# 2020-04-16  7116.804199
# 2020-04-17  7096.184570
# 2020-04-18  7257.665039
# 2020-04-19  7189.424805

# %%
#Read in the CSV file called "ETH_USD.csv" using the path module. 
eth_path = Path('../PROJECT_I_dev/csv_files_crypto/ETH_USD.csv')

#Read eth csv into pandas dataframe, indexing date.
eth_df = pd.read_csv(
        eth_path, index_col='Date', infer_datetime_format=True, parse_dates=True
)

# %%
#Verify 'close' data-type as "float." 
eth_df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Filter out 'close' price into sliced dataframe. 
eth_sliced=eth_df.iloc[:,[3]]

# %%
#Rename 'close' price to 'ETH/USD' in a new dataframe.
eth_new = eth_sliced.rename(columns={"Close":"ETH/USD"})

#Review top 5 results.
eth_new.head()
# Out:
#                ETH/USD
# Date
# 2020-04-15  153.286896
# 2020-04-16  172.157379
# 2020-04-17  171.638580
# 2020-04-18  186.914001
# 2020-04-19  181.614960

# %%
#Read in the CSV file called "XLM_USD.csv" using the path module. 
xlm_path = Path('../PROJECT_I_dev/csv_files_crypto/XLM_USD.csv')

#Read xlm csv into pandas dataframe, indexing date.
xlm_df = pd.read_csv(
        xlm_path, index_col='Date', infer_datetime_format=True, parse_dates=True
)

# %%
#Verify 'close' data-type as float. 
xlm_df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Filter out 'close' price into sliced dataframe. 
xlm_sliced = xlm_df.iloc[:,[3]]

# %%
#Rename 'close' price to 'XLM/USD' in a new dataframe. 
xlm_new = xlm_sliced.rename(columns={"Close":"XLM/USD"})

#Review the top 5 results.
xlm_new.head()
# Out:
#              XLM/USD
# Date
# 2020-04-15  0.046409
# 2020-04-16  0.049125
# 2020-04-17  0.049070
# 2020-04-18  0.050501
# 2020-04-19  0.049209

# %%
#Read in the CSV file called "XMR_USD.csv" using the path module. 
xmr_path = Path('../PROJECT_I_dev/csv_files_crypto/XMR_USD.csv')

#Read xmr csv into pandas dataframe, indexing date.
xmr_df = pd.read_csv(
        xmr_path, index_col='Date', infer_datetime_format=True, parse_dates=True
)

# %%
#Verify 'close' data-type as "float."
xmr_df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Filter out 'close' price into sliced dataframe. 
xmr_sliced = xmr_df.iloc[:,[3]]

# %%
#Rename 'close' price to 'XMR/USD' in a new dataframe.
xmr_new = xmr_sliced.rename(columns={"Close":"XMR/USD"})

#Display the top 5 results.
xmr_new.head()
# Out:
#               XMR/USD
# Date
# 2020-04-15  53.153870
# 2020-04-16  56.884686
# 2020-04-17  56.552799
# 2020-04-18  57.972260
# 2020-04-19  57.447842

# %%
#Use concatenate function to group btc_new, eth_new, trx_new, xlm_new, xmr_new dataframes into a single dataframe called 'crypto.'
crypto = pd.concat([btc_new, eth_new, trx_new, xlm_new, xmr_new], axis=1)
#Display results. 
crypto
# Out:
#                  BTC/USD      ETH/USD   TRX/USD   XLM/USD     XMR/USD
# Date
# 2020-04-15   6642.109863   153.286896  0.012225  0.046409   53.153870
# 2020-04-16   7116.804199   172.157379  0.013042  0.049125   56.884686
# 2020-04-17   7096.184570   171.638580  0.013004  0.049070   56.552799
# 2020-04-18   7257.665039   186.914001  0.013369  0.050501   57.972260
# 2020-04-19   7189.424805   181.614960  0.013032  0.049209   57.447842
# ...                  ...          ...       ...       ...         ...
# 2021-12-27  50640.417969  4037.547607  0.081002  0.298911  220.451660
# 2021-12-28  47588.855469  3800.893066  0.077259  0.274574  208.804703
# 2021-12-29  46444.710938  3628.531738  0.076466  0.266442  214.467850
# 2021-12-30  47178.125000  3713.852051  0.077924  0.268325  225.748016
# 2021-12-31  46306.445313  3682.632813  0.075397  0.267394  228.824951
#
# [626 rows x 5 columns]

# %%
crypto_daily_returns = crypto.pct_change()
crypto_daily_returns.head()

# %%
#Define the stimulus amount in a new variable.
starting_value = float(input("Starting amount"))

# %%
starting_value

# %%
#Calculate daily returns for xlm in a new dataframe. 
xlm_daily_returns = xlm_new.pct_change()

xlm_daily_returns.head()

# %%
#Add an empty portfolio column to XLM Daily Returns. 
xlm_daily_returns['Portfolio'] = pd.NaT

xlm_daily_returns

# %%
#Calculate the portfolio value over time. 
xlm_daily_returns = xlm_daily_returns.assign(Portfolio=(1+xlm_daily_returns['XLM/USD'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
xlm = xlm_daily_returns.rename(columns={'XLM/USD':'XLM Daily Returns',"Portfolio":"XLM Port"})

# %%
#Display results. 
xlm.head()

# %%
#Calculate daily returns for XMR in a new dataframe. 
xmr_daily_returns = xmr_new.pct_change()

# %%
#Add an empty portfolio column to XMR Daily Returns. 
xmr_daily_returns['Portfolio'] = pd.NaT

xmr_daily_returns

# %%
#Calculate the portfolio value over time. 
xmr_daily_returns = xmr_daily_returns.assign(Portfolio=(1+xmr_daily_returns['XMR/USD'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
xmr = xmr_daily_returns.rename(columns={'XMR/USD':'XMR Daily Returns',"Portfolio":"XMR Port"})

# %%
#Display results.
xmr.head()

# %%
#Calculate daily returns for ETH in a new dataframe. 
eth_daily_returns = eth_new.pct_change()

# %%
#Add an empty portfolio column to ETH Daily Returns. 
eth_daily_returns['Portfolio'] = pd.NaT

eth_daily_returns
# Out:
#              ETH/USD Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16  0.123106       NaT
# 2020-04-17 -0.003014       NaT
# 2020-04-18  0.088998       NaT
# 2020-04-19 -0.028350       NaT
# ...              ...       ...
# 2021-12-27 -0.007322       NaT
# 2021-12-28 -0.058613       NaT
# 2021-12-29 -0.045348       NaT
# 2021-12-30  0.023514       NaT
# 2021-12-31 -0.008406       NaT
#
# [626 rows x 2 columns]

# %%
#Calculate the portfolio value over time. 
eth_daily_returns = eth_daily_returns.assign(Portfolio=(1+eth_daily_returns['ETH/USD'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
eth = eth_daily_returns.rename(columns={'ETH/USD':'ETH Daily Returns',"Portfolio":"ETH Port"})

# %%
#Display results.
eth.tail()
# Out:
#             ETH Daily Returns      ETH Port
# Date
# 2021-12-27          -0.007322  31607.771146
# 2021-12-28          -0.058613  29755.131053
# 2021-12-29          -0.045348  28405.807667
# 2021-12-30           0.023514  29073.734138
# 2021-12-31          -0.008406  28829.335650

# %%
#Calculate daily returns for BTC in a new dataframe. 
btc_daily_returns = btc_new.pct_change()

# %%
#Add an empty portfolio column to BTC Daily Returns. 
btc_daily_returns['Portfolio'] = pd.NaT

btc_daily_returns
# Out:
#              BTC/USD Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16  0.071467       NaT
# 2020-04-17 -0.002897       NaT
# 2020-04-18  0.022756       NaT
# 2020-04-19 -0.009403       NaT
# ...              ...       ...
# 2021-12-27 -0.003328       NaT
# 2021-12-28 -0.060259       NaT
# 2021-12-29 -0.024042       NaT
# 2021-12-30  0.015791       NaT
# 2021-12-31 -0.018476       NaT
#
# [626 rows x 2 columns]

# %%
#Calculate the portfolio value over time. 
btc_daily_returns = btc_daily_returns.assign(Portfolio=(1+btc_daily_returns['BTC/USD'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
btc = btc_daily_returns.rename(columns={'BTC/USD':'BTC Daily Returns',"Portfolio":"BTC Port"})

# %%
#Display results.
btc.tail()
# Out:
#             BTC Daily Returns     BTC Port
# Date
# 2021-12-27          -0.003328  9148.975674
# 2021-12-28          -0.060259  8597.663655
# 2021-12-29          -0.024042  8390.956229
# 2021-12-30           0.015791  8523.458836
# 2021-12-31          -0.018476  8365.976402

# %%
#Calculate daily returns for TRX in a new dataframe. 
trx_daily_returns = trx_new.pct_change()

# %%
#Add an empty portfolio column to TRX Daily Returns. 
trx_daily_returns['Portfolio'] = pd.NaT

trx_daily_returns
# Out:
#              TRX/USD Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16  0.066830       NaT
# 2020-04-17 -0.002914       NaT
# 2020-04-18  0.028068       NaT
# 2020-04-19 -0.025208       NaT
# ...              ...       ...
# 2021-12-27 -0.007036       NaT
# 2021-12-28 -0.046209       NaT
# 2021-12-29 -0.010264       NaT
# 2021-12-30  0.019067       NaT
# 2021-12-31 -0.032429       NaT
#
# [626 rows x 2 columns]

# %%
#Calculate the portfolio value over time. 
trx_daily_returns = trx_daily_returns.assign(Portfolio=(1+trx_daily_returns['TRX/USD'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
trx = trx_daily_returns.rename(columns={'TRX/USD':'TRX Daily Returns',"Portfolio":"TRX Port"})

# %%
#Display results.
trx.tail()
# Out:
#             TRX Daily Returns     TRX Port
# Date
# 2021-12-27          -0.007036  7951.116564
# 2021-12-28          -0.046209  7583.705521
# 2021-12-29          -0.010264  7505.865031
# 2021-12-30           0.019067  7648.981595
# 2021-12-31          -0.032429  7400.932515

# %%
#Use concatenate function to group the daily_returns and port values into one dataframe. 
crypto_new = pd.concat([btc, eth, trx, xmr, xlm],axis=1)

#Display results.
crypto_new
# Out:
#             BTC Daily Returns     BTC Port  ETH Daily Returns      ETH Port  \
# Date
# 2020-04-15                NaN  1200.000000                NaN   1200.000000
# 2020-04-16           0.071467  1285.760882           0.123106   1347.726780
# 2020-04-17          -0.002897  1282.035627          -0.003014   1343.665384
# 2020-04-18           0.022756  1311.209574           0.088998   1463.248373
# 2020-04-19          -0.009403  1298.880919          -0.028350   1421.765054
# ...                       ...          ...                ...           ...
# 2021-12-27          -0.003328  9148.975674          -0.007322  31607.771146
# 2021-12-28          -0.060259  8597.663655          -0.058613  29755.131053
# 2021-12-29          -0.024042  8390.956229          -0.045348  28405.807667
# 2021-12-30           0.015791  8523.458836           0.023514  29073.734138
# 2021-12-31          -0.018476  8365.976402          -0.008406  28829.335650
#
#             TRX Daily Returns     TRX Port  XMR Daily Returns     XMR Port  \
# Date
# 2020-04-15                NaN  1200.000000                NaN  1200.000000
# 2020-04-16           0.066830  1280.196319           0.070189  1284.226778
# 2020-04-17          -0.002914  1276.466258          -0.005834  1276.734108
# 2020-04-18           0.028068  1312.294479           0.025100  1308.779812
# 2020-04-19          -0.025208  1279.214724          -0.009046  1296.940569
# ...                       ...          ...                ...          ...
# 2021-12-27          -0.007036  7951.116564           0.015398  4976.909339
# 2021-12-28          -0.046209  7583.705521          -0.052832  4713.968025
# 2021-12-29          -0.010264  7505.865031           0.027122  4841.819043
# 2021-12-30           0.019067  7648.981595           0.052596  5096.479696
# 2021-12-31          -0.032429  7400.932515           0.013630  5165.944478
#
#             XLM Daily Returns     XLM Port
# Date
# 2020-04-15                NaN  1200.000000
# 2020-04-16           0.058523  1270.227758
# 2020-04-17          -0.001120  1268.805620
# 2020-04-18           0.029162  1305.807063
# 2020-04-19          -0.025584  1272.399750
# ...                       ...          ...
# 2021-12-27           0.025529  7728.957745
# 2021-12-28          -0.081419  7099.674632
# 2021-12-29          -0.029617  6889.405072
# 2021-12-30           0.007067  6938.093904
# 2021-12-31          -0.003470  6914.020987
#
# [626 rows x 10 columns]

# %%
crypto_new.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Drop 'Daily Returns' column. 
crypto_sliced = crypto_new.iloc[:,[1,3,5,7,9]]
crypto_sliced
# Out:
#                BTC Port      ETH Port     TRX Port     XMR Port     XLM Port
# Date
# 2020-04-15  1200.000000   1200.000000  1200.000000  1200.000000  1200.000000
# 2020-04-16  1285.760882   1347.726780  1280.196319  1284.226778  1270.227758
# 2020-04-17  1282.035627   1343.665384  1276.466258  1276.734108  1268.805620
# 2020-04-18  1311.209574   1463.248373  1312.294479  1308.779812  1305.807063
# 2020-04-19  1298.880919   1421.765054  1279.214724  1296.940569  1272.399750
# ...                 ...           ...          ...          ...          ...
# 2021-12-27  9148.975674  31607.771146  7951.116564  4976.909339  7728.957745
# 2021-12-28  8597.663655  29755.131053  7583.705521  4713.968025  7099.674632
# 2021-12-29  8390.956229  28405.807667  7505.865031  4841.819043  6889.405072
# 2021-12-30  8523.458836  29073.734138  7648.981595  5096.479696  6938.093904
# 2021-12-31  8365.976402  28829.335650  7400.932515  5165.944478  6914.020987
#
# [626 rows x 5 columns]

# %%
#Build a figure for all series
fig = px.line(crypto_sliced, x=crypto_sliced.index, y = crypto_sliced.columns)
#Map lines/series to groups
maps = {'group 1': ['BTC Port', 'ETH Port'],
           'group 2':['TRX Port', 'XMR Port', "XLM Port"]}

#Create group and trace visibilites
group = []
vis = []
visList = []
for m in maps.keys():
    for col in crypto_sliced.columns:
        if col in maps[m]:
            vis.append(True)
        else:
            vis.append(False)
    group.append(m)
    visList.append(vis)
    vis = []
    
#Create buttons for each group
buttons = []
for i, g in enumerate(group):
    button =  dict(label=g,
                   method = 'restyle',
                    args = ['visible',visList[i]])
    buttons.append(button)

buttons = [{'label': 'all',
                 'method': 'restyle',
                 'args': ['visible', [True, True, True, True, True, True]]}] + buttons

                     

# update layout with buttons                       
fig.update_layout(
    updatemenus=[
        dict(
        type="dropdown",
        direction="down",
        buttons = buttons)
    ],
)
# buttons
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0x/x4nws4v11vj2wn0bd7g59v0m0000gn/T/ipykernel_35472/1165795495.py in <module>
#       1 #Build a figure for all series
# ----> 2 fig = px.line(crypto_sliced, x=crypto_sliced.index, y = crypto_sliced.columns)
#       3 #Map lines/series to groups
#       4 maps = {'group 1': ['BTC Port', 'ETH Port'],
#       5            'group 2':['TRX Port', 'XMR Port', "XLM Port"]}
#
# NameError: name 'crypto_sliced' is not defined

# %%
#Create a dataframe to filter out daily returns % change.
crypto_sliced_vol = crypto_new.iloc[:,[0,2,4,6,8]]
crypto_sliced_vol
# Out:
#             BTC Daily Returns  ETH Daily Returns  TRX Daily Returns  \
# Date
# 2020-04-15                NaN                NaN                NaN
# 2020-04-16           0.071467           0.123106           0.066830
# 2020-04-17          -0.002897          -0.003014          -0.002914
# 2020-04-18           0.022756           0.088998           0.028068
# 2020-04-19          -0.009403          -0.028350          -0.025208
# ...                       ...                ...                ...
# 2021-12-27          -0.003328          -0.007322          -0.007036
# 2021-12-28          -0.060259          -0.058613          -0.046209
# 2021-12-29          -0.024042          -0.045348          -0.010264
# 2021-12-30           0.015791           0.023514           0.019067
# 2021-12-31          -0.018476          -0.008406          -0.032429
#
#             XMR Daily Returns  XLM Daily Returns
# Date
# 2020-04-15                NaN                NaN
# 2020-04-16           0.070189           0.058523
# 2020-04-17          -0.005834          -0.001120
# 2020-04-18           0.025100           0.029162
# 2020-04-19          -0.009046          -0.025584
# ...                       ...                ...
# 2021-12-27           0.015398           0.025529
# 2021-12-28          -0.052832          -0.081419
# 2021-12-29           0.027122          -0.029617
# 2021-12-30           0.052596           0.007067
# 2021-12-31           0.013630          -0.003470
#
# [626 rows x 5 columns]

# %%
#Create a plot for daily returns to demonstrate volatility. 
#Build a figure for all series
fig = px.line(crypto_sliced_vol, x=crypto_sliced_vol.index, y = crypto_sliced_vol.columns,)
#Map lines/series to groups
maps = {'group 1': ['BTC Daily Returns', 'ETH Daily Returns'],
           'group 2':['TRX Daily Returns', 'XMR Daily Returns', "XLM Daily Returns"]}

#Create group and trace visibilites
group = []
vis = []
visList = []
for m in maps.keys():
    for col in crypto_sliced_vol.columns:
        if col in maps[m]:
            vis.append(True)
        else:
            vis.append(False)
    group.append(m)
    visList.append(vis)
    vis = []
    
#Create buttons for each group
buttons = []
for i, g in enumerate(group):
    button =  dict(label=g,
                   method = 'restyle',
                    args = ['visible',visList[i]])
    buttons.append(button)

buttons = [{'label': 'all',
                 'method': 'restyle',
                 'args': ['visible', [True, True, True, True, True, True]]}] + buttons

                     

# update layout with buttons                       
fig.update_layout(
    updatemenus=[
        dict(
        type="dropdown",
        direction="down",
        buttons = buttons)
    ],
)
# buttons
fig.show()
