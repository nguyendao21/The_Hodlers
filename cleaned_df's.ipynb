# %%
import sys 
import fire
import csv
import questionary
import pandas as pd 
from pathlib import Path

import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
wheat_df = pd.read_csv(
    Path("../Resources/zw_wheat.csv"),
    index_col='Date',
    parse_dates=True,
    infer_datetime_format=True
)


wheat_df = wheat_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
wheat_df
# Out:
#             Close/Last
# Date
# 2022-01-20      790.25
# 2022-01-19      796.50
# 2022-01-18      769.00
# 2022-01-14      741.50
# 2022-01-13      746.75
# ...                ...
# 2017-01-26      420.50
# 2017-01-25      427.00
# 2017-01-24      424.50
# 2017-01-23      426.75
# 2017-01-20      428.25
#
# [1260 rows x 1 columns]

# %%
wheat_df = wheat_df.rename(columns={'Close/Last' : 'Wheat'})
wheat_df
# Out:
#              Wheat
# Date
# 2022-01-20  790.25
# 2022-01-19  796.50
# 2022-01-18  769.00
# 2022-01-14  741.50
# 2022-01-13  746.75
# ...            ...
# 2017-01-26  420.50
# 2017-01-25  427.00
# 2017-01-24  424.50
# 2017-01-23  426.75
# 2017-01-20  428.25
#
# [1260 rows x 1 columns]

# %%
# Filtering my dataframes so that dates that are unused are removed.


wheat_cleaned = wheat_df.sort_index().truncate(before = '04/15/2020', after ='12/31/2021')
wheat_cleaned.head()
# Out:
#              Wheat
# Date
# 2020-04-15  540.50
# 2020-04-16  530.50
# 2020-04-17  533.75
# 2020-04-20  547.50
# 2020-04-21  548.75

# %%
wheat_cleaned.dtypes
# Out:
# Wheat    float64
# dtype: object

# %%
corn_df = pd.read_csv(
    Path("../Resources/zc_corn.csv"),
    index_col='Date',
    parse_dates=True,
    infer_datetime_format=True
)

corn_df = corn_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
corn_df
# Out:
#             Close/Last
# Date
# 2022-01-20      611.00
# 2022-01-19      610.50
# 2022-01-18      599.50
# 2022-01-14      596.25
# 2022-01-13      587.50
# ...                ...
# 2017-01-26      363.75
# 2017-01-25      366.25
# 2017-01-24      363.25
# 2017-01-23      369.50
# 2017-01-20      369.75
#
# [1260 rows x 1 columns]

# %%
corn_df = corn_df.rename(columns={'Close/Last' : 'Corn'})
corn_df
# Out:
#               Corn
# Date
# 2022-01-20  611.00
# 2022-01-19  610.50
# 2022-01-18  599.50
# 2022-01-14  596.25
# 2022-01-13  587.50
# ...            ...
# 2017-01-26  363.75
# 2017-01-25  366.25
# 2017-01-24  363.25
# 2017-01-23  369.50
# 2017-01-20  369.75
#
# [1260 rows x 1 columns]

# %%
# Filtering my dataframes so that dates that are unused are removed.
corn_cleaned = corn_df.sort_index().truncate(before = '04/15/2020', after ='12/31/2021')
corn_cleaned
# Out:
#               Corn
# Date
# 2020-04-15  319.25
# 2020-04-16  319.75
# 2020-04-17  322.25
# 2020-04-20  314.25
# 2020-04-21  309.25
# ...            ...
# 2021-12-27  614.75
# 2021-12-28  604.75
# 2021-12-29  605.50
# 2021-12-30  596.00
# 2021-12-31  593.25
#
# [434 rows x 1 columns]

# %%
fd_cattle_df = pd.read_csv(
    Path("../Resources/fd_cattle.csv"),
    index_col='Date',
    parse_dates=True,
    infer_datetime_format=True
)

fd_cattle_df = fd_cattle_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
fd_cattle_df
# Out:
#             Close/Last
# Date
# 2022-01-20     138.325
# 2022-01-19     138.550
# 2022-01-18     137.675
# 2022-01-14     137.975
# 2022-01-13     137.000
# ...                ...
# 2017-01-26     118.700
# 2017-01-25     119.875
# 2017-01-24     119.675
# 2017-01-23     120.250
# 2017-01-20     120.250
#
# [1260 rows x 1 columns]

# %%
fd_cattle_df = fd_cattle_df.rename(columns={'Close/Last' : 'FD Cattle'})
fd_cattle_df
# Out:
#             FD Cattle
# Date
# 2022-01-20    138.325
# 2022-01-19    138.550
# 2022-01-18    137.675
# 2022-01-14    137.975
# 2022-01-13    137.000
# ...               ...
# 2017-01-26    118.700
# 2017-01-25    119.875
# 2017-01-24    119.675
# 2017-01-23    120.250
# 2017-01-20    120.250
#
# [1260 rows x 1 columns]

# %%
# Filtering my dataframes so that dates that are unused are removed.
fd_cattle_cleaned = fd_cattle_df.sort_index().truncate(before = '04/15/2020', after ='12/31/2021')
fd_cattle_cleaned.head()
# Out:
#             FD Cattle
# Date
# 2020-04-15     94.725
# 2020-04-16     95.500
# 2020-04-17     94.650
# 2020-04-20     93.525
# 2020-04-21     91.600

# %%
fd_cattle_cleaned.dtypes
# Out:
# FD Cattle    float64
# dtype: object

# %%
hogs_df = pd.read_csv(
    Path("../Resources/he_hogs.csv"),
    index_col='Date',
    parse_dates=True,
    infer_datetime_format=True
)

hogs_df = hogs_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
hogs_df
# Out:
#             Close/Last
# Date
# 2022-01-20      94.000
# 2022-01-19      91.350
# 2022-01-18      89.275
# 2022-01-14      88.450
# 2022-01-13      85.325
# ...                ...
# 2017-01-26      67.225
# 2017-01-25      70.150
# 2017-01-24      67.625
# 2017-01-23      67.775
# 2017-01-20      68.475
#
# [1260 rows x 1 columns]

# %%
hogs_df = hogs_df.rename(columns={'Close/Last' : 'Hogs'})
hogs_df
# Out:
#               Hogs
# Date
# 2022-01-20  94.000
# 2022-01-19  91.350
# 2022-01-18  89.275
# 2022-01-14  88.450
# 2022-01-13  85.325
# ...            ...
# 2017-01-26  67.225
# 2017-01-25  70.150
# 2017-01-24  67.625
# 2017-01-23  67.775
# 2017-01-20  68.475
#
# [1260 rows x 1 columns]

# %%
# Filtering my dataframes so that dates that are unused are removed.
hogs_cleaned = hogs_df.sort_index().truncate(before = '04/15/2020', after ='12/31/2021')
hogs_cleaned
# Out:
#               Hogs
# Date
# 2020-04-15  44.625
# 2020-04-16  43.175
# 2020-04-17  43.725
# 2020-04-20  46.250
# 2020-04-21  52.925
# ...            ...
# 2021-12-27  83.650
# 2021-12-28  82.625
# 2021-12-29  83.825
# 2021-12-30  82.700
# 2021-12-31  81.475
#
# [434 rows x 1 columns]

# %%
hogs_cleaned.dtypes
# Out:
# Hogs    float64
# dtype: object

# %%
gf_cattle = pd.read_csv(
    Path("../Resources/gf_cattle.csv"),
    index_col='Date',
    parse_dates=True,
    infer_datetime_format=True
)

gf_cattle = gf_cattle.drop(columns=['Volume', 'Open', 'High', 'Low'])

# %%
gf_cattle = gf_cattle.rename(columns={'Close/Last' : 'GF Cattle'})
gf_cattle
# Out:
#             GF Cattle
# Date
# 2022-01-21    163.300
# 2022-01-20    164.950
# 2022-01-19    165.625
# 2022-01-18    165.425
# 2022-01-14    166.375
# ...               ...
# 2017-01-27    127.450
# 2017-01-26    127.100
# 2017-01-25    129.850
# 2017-01-24    130.175
# 2017-01-23    130.675
#
# [1260 rows x 1 columns]

# %%
# Filtering my dataframes so that dates that are unused are removed.
gf_cattle_cleaned = gf_cattle.sort_index().truncate(before = '04/15/2020', after ='12/31/2021')
gf_cattle_cleaned
# Out:
#             GF Cattle
# Date
# 2020-04-15    115.575
# 2020-04-16    128.625
# 2020-04-17    128.400
# 2020-04-20    127.650
# 2020-04-21    116.750
# ...               ...
# 2021-12-27    163.275
# 2021-12-28    165.225
# 2021-12-29    168.050
# 2021-12-30    169.000
# 2021-12-31    169.950
#
# [434 rows x 1 columns]

# %%
# Using Concat to combine all dataframes into one

agriculture_df_closing_price = pd.concat([wheat_cleaned, corn_cleaned, fd_cattle_cleaned, hogs_cleaned, gf_cattle_cleaned], axis = 1, join = "inner")
agriculture_df_closing_price
# Out:
#              Wheat    Corn  FD Cattle    Hogs  GF Cattle
# Date
# 2020-04-15  540.50  319.25     94.725  44.625    115.575
# 2020-04-16  530.50  319.75     95.500  43.175    128.625
# 2020-04-17  533.75  322.25     94.650  43.725    128.400
# 2020-04-20  547.50  314.25     93.525  46.250    127.650
# 2020-04-21  548.75  309.25     91.600  52.925    116.750
# ...            ...     ...        ...     ...        ...
# 2021-12-27  804.00  614.75    137.300  83.650    163.275
# 2021-12-28  783.50  604.75    138.475  82.625    165.225
# 2021-12-29  787.75  605.50    139.400  83.825    168.050
# 2021-12-30  779.75  596.00    139.050  82.700    169.000
# 2021-12-31  770.75  593.25    138.900  81.475    169.950
#
# [434 rows x 5 columns]

# %%
agriculture_df_daily_returns = agriculture_df_closing_price.pct_change().dropna()

# %%
agriculture_df_daily_returns
# Out:
#                Wheat      Corn  FD Cattle      Hogs  GF Cattle
# Date
# 2020-04-16 -0.018501  0.001566   0.008182 -0.032493   0.112914
# 2020-04-17  0.006126  0.007819  -0.008901  0.012739  -0.001749
# 2020-04-20  0.025761 -0.024825  -0.011886  0.057747  -0.005841
# 2020-04-21  0.002283 -0.015911  -0.020583  0.144324  -0.085390
# 2020-04-22 -0.009112  0.026677  -0.028930 -0.094946   0.089507
# ...              ...       ...        ...       ...        ...
# 2021-12-27 -0.013194  0.014858   0.001824  0.005107  -0.002901
# 2021-12-28 -0.025498 -0.016267   0.008558 -0.012253   0.011943
# 2021-12-29  0.005424  0.001240   0.006680  0.014523   0.017098
# 2021-12-30 -0.010156 -0.015690  -0.002511 -0.013421   0.005653
# 2021-12-31 -0.011542 -0.004614  -0.001079 -0.014813   0.005621
#
# [433 rows x 5 columns]

# %%
#define the stimulus starting amoung in var
starting_value= float(input("starting amount"))
# Out:
# starting amount 1200

# %%
starting_value
# Out:
# 1200.0

# %%
# Calculate daily returns for Wheat in a new dataframe

wheat_daily_returns = wheat_cleaned.pct_change()

wheat_daily_returns.head()
# Out:
#                Wheat
# Date
# 2020-04-15       NaN
# 2020-04-16 -0.018501
# 2020-04-17  0.006126
# 2020-04-20  0.025761
# 2020-04-21  0.002283

# %%
wheat_daily_returns['Portfolio'] = pd.NaT

wheat_daily_returns
# Out:
#                Wheat Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16 -0.018501       NaT
# 2020-04-17  0.006126       NaT
# 2020-04-20  0.025761       NaT
# 2020-04-21  0.002283       NaT
# ...              ...       ...
# 2021-12-27 -0.013194       NaT
# 2021-12-28 -0.025498       NaT
# 2021-12-29  0.005424       NaT
# 2021-12-30 -0.010156       NaT
# 2021-12-31 -0.011542       NaT
#
# [434 rows x 2 columns]

# %%
wheat_daily_returns = wheat_daily_returns.assign(Portfolio=(1+wheat_daily_returns['Wheat'].fillna(0)).cumprod().mul(starting_value))

# %%
#Rename columns. 
wheat = wheat_daily_returns.rename(columns={'Wheat':'Wheat Daily Returns',"Portfolio":"Wheat Port"})

# %%
wheat.head()
# Out:
#             Wheat Daily Returns   Wheat Port
# Date
# 2020-04-15                  NaN  1200.000000
# 2020-04-16            -0.018501  1177.798335
# 2020-04-17             0.006126  1185.013876
# 2020-04-20             0.025761  1215.541166
# 2020-04-21             0.002283  1218.316374

# %%
corn_daily_returns = corn_cleaned.pct_change()

corn_daily_returns.head()
# Out:
#                 Corn
# Date
# 2020-04-15       NaN
# 2020-04-16  0.001566
# 2020-04-17  0.007819
# 2020-04-20 -0.024825
# 2020-04-21 -0.015911

# %%
corn_daily_returns['Portfolio'] = pd.NaT

corn_daily_returns
# Out:
#                 Corn Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16  0.001566       NaT
# 2020-04-17  0.007819       NaT
# 2020-04-20 -0.024825       NaT
# 2020-04-21 -0.015911       NaT
# ...              ...       ...
# 2021-12-27  0.014858       NaT
# 2021-12-28 -0.016267       NaT
# 2021-12-29  0.001240       NaT
# 2021-12-30 -0.015690       NaT
# 2021-12-31 -0.004614       NaT
#
# [434 rows x 2 columns]

# %%
corn_daily_returns = corn_daily_returns.assign(Portfolio=(1+corn_daily_returns['Corn'].fillna(0)).cumprod().mul(starting_value))

# %%
corn = corn_daily_returns.rename(columns={'Corn':'Corn Daily Returns',"Portfolio":"Corn Port"})

# %%
corn.tail()
# Out:
#             Corn Daily Returns    Corn Port
# Date
# 2021-12-27            0.014858  2310.728269
# 2021-12-28           -0.016267  2273.140172
# 2021-12-29            0.001240  2275.959280
# 2021-12-30           -0.015690  2240.250587
# 2021-12-31           -0.004614  2229.913861

# %%
fd_cattle_daily_returns = fd_cattle_cleaned.pct_change()

fd_cattle_daily_returns.head()
# Out:
#             FD Cattle
# Date
# 2020-04-15        NaN
# 2020-04-16   0.008182
# 2020-04-17  -0.008901
# 2020-04-20  -0.011886
# 2020-04-21  -0.020583

# %%
fd_cattle_daily_returns['Portfolio'] = pd.NaT

fd_cattle_daily_returns
# Out:
#             FD Cattle Portfolio
# Date
# 2020-04-15        NaN       NaT
# 2020-04-16   0.008182       NaT
# 2020-04-17  -0.008901       NaT
# 2020-04-20  -0.011886       NaT
# 2020-04-21  -0.020583       NaT
# ...               ...       ...
# 2021-12-27   0.001824       NaT
# 2021-12-28   0.008558       NaT
# 2021-12-29   0.006680       NaT
# 2021-12-30  -0.002511       NaT
# 2021-12-31  -0.001079       NaT
#
# [434 rows x 2 columns]

# %%
fd_cattle_daily_returns = fd_cattle_daily_returns.assign(Portfolio=(1+fd_cattle_daily_returns['FD Cattle'].fillna(0)).cumprod().mul(starting_value))

# %%
fd_cattle = fd_cattle_daily_returns.rename(columns={'FD Cattle':'FD Cattle Daily Returns',"Portfolio":"FD Cattle Port"})

# %%
fd_cattle
# Out:
#             FD Cattle Daily Returns  FD Cattle Port
# Date
# 2020-04-15                      NaN     1200.000000
# 2020-04-16                 0.008182     1209.817894
# 2020-04-17                -0.008901     1199.049881
# 2020-04-20                -0.011886     1184.798100
# 2020-04-21                -0.020583     1160.411718
# ...                             ...             ...
# 2021-12-27                 0.001824     1739.350752
# 2021-12-28                 0.008558     1754.235946
# 2021-12-29                 0.006680     1765.954078
# 2021-12-30                -0.002511     1761.520190
# 2021-12-31                -0.001079     1759.619952
#
# [434 rows x 2 columns]

# %%
hogs_daily_returns = hogs_cleaned.pct_change()

hogs_daily_returns.head()
# Out:
#                 Hogs
# Date
# 2020-04-15       NaN
# 2020-04-16 -0.032493
# 2020-04-17  0.012739
# 2020-04-20  0.057747
# 2020-04-21  0.144324

# %%
hogs_daily_returns['Portfolio'] = pd.NaT

hogs_daily_returns
# Out:
#                 Hogs Portfolio
# Date
# 2020-04-15       NaN       NaT
# 2020-04-16 -0.032493       NaT
# 2020-04-17  0.012739       NaT
# 2020-04-20  0.057747       NaT
# 2020-04-21  0.144324       NaT
# ...              ...       ...
# 2021-12-27  0.005107       NaT
# 2021-12-28 -0.012253       NaT
# 2021-12-29  0.014523       NaT
# 2021-12-30 -0.013421       NaT
# 2021-12-31 -0.014813       NaT
#
# [434 rows x 2 columns]

# %%
hogs_daily_returns = hogs_daily_returns.assign(Portfolio=(1+hogs_daily_returns['Hogs'].fillna(0)).cumprod().mul(starting_value))

# %%
hogs = hogs_daily_returns.rename(columns={'Hogs':'Hogs Daily Returns',"Portfolio":"Hogs Port"})
hogs.head()
# Out:
#             Hogs Daily Returns    Hogs Port
# Date
# 2020-04-15                 NaN  1200.000000
# 2020-04-16           -0.032493  1161.008403
# 2020-04-17            0.012739  1175.798319
# 2020-04-20            0.057747  1243.697479
# 2020-04-21            0.144324  1423.193277

# %%
gf_cattle_daily_returns = gf_cattle_cleaned.pct_change()

gf_cattle_daily_returns.head()
# Out:
#             GF Cattle
# Date
# 2020-04-15        NaN
# 2020-04-16   0.112914
# 2020-04-17  -0.001749
# 2020-04-20  -0.005841
# 2020-04-21  -0.085390

# %%
gf_cattle_daily_returns['Portfolio'] = pd.NaT

gf_cattle_daily_returns
# Out:
#             GF Cattle Portfolio
# Date
# 2020-04-15        NaN       NaT
# 2020-04-16   0.112914       NaT
# 2020-04-17  -0.001749       NaT
# 2020-04-20  -0.005841       NaT
# 2020-04-21  -0.085390       NaT
# ...               ...       ...
# 2021-12-27  -0.002901       NaT
# 2021-12-28   0.011943       NaT
# 2021-12-29   0.017098       NaT
# 2021-12-30   0.005653       NaT
# 2021-12-31   0.005621       NaT
#
# [434 rows x 2 columns]

# %%
gf_cattle_daily_returns = gf_cattle_daily_returns.assign(Portfolio=(1+gf_cattle_daily_returns['GF Cattle'].fillna(0)).cumprod().mul(starting_value))

# %%
gf_cattle = gf_cattle_daily_returns.rename(columns={'FD Cattle':'FD Cattle Daily Returns',"Portfolio":"GF Cattle Port"})
gf_cattle.head()
# Out:
#             GF Cattle  GF Cattle Port
# Date
# 2020-04-15        NaN     1200.000000
# 2020-04-16   0.112914     1335.496431
# 2020-04-17  -0.001749     1333.160286
# 2020-04-20  -0.005841     1325.373134
# 2020-04-21  -0.085390     1212.199870

# %%
agriculture_daily_returns = pd.concat([wheat, corn, fd_cattle, hogs, gf_cattle], axis=1)

# %%
agriculture_daily_returns
# Out:
#             Wheat Daily Returns   Wheat Port  Corn Daily Returns    Corn Port  \
# Date
# 2020-04-15                  NaN  1200.000000                 NaN  1200.000000
# 2020-04-16            -0.018501  1177.798335            0.001566  1201.879405
# 2020-04-17             0.006126  1185.013876            0.007819  1211.276429
# 2020-04-20             0.025761  1215.541166           -0.024825  1181.205951
# 2020-04-21             0.002283  1218.316374           -0.015911  1162.411903
# ...                         ...          ...                 ...          ...
# 2021-12-27            -0.013194  1785.013876            0.014858  2310.728269
# 2021-12-28            -0.025498  1739.500463           -0.016267  2273.140172
# 2021-12-29             0.005424  1748.936170            0.001240  2275.959280
# 2021-12-30            -0.010156  1731.174838           -0.015690  2240.250587
# 2021-12-31            -0.011542  1711.193340           -0.004614  2229.913861
#
#             FD Cattle Daily Returns  FD Cattle Port  Hogs Daily Returns  \
# Date
# 2020-04-15                      NaN     1200.000000                 NaN
# 2020-04-16                 0.008182     1209.817894           -0.032493
# 2020-04-17                -0.008901     1199.049881            0.012739
# 2020-04-20                -0.011886     1184.798100            0.057747
# 2020-04-21                -0.020583     1160.411718            0.144324
# ...                             ...             ...                 ...
# 2021-12-27                 0.001824     1739.350752            0.005107
# 2021-12-28                 0.008558     1754.235946           -0.012253
# 2021-12-29                 0.006680     1765.954078            0.014523
# 2021-12-30                -0.002511     1761.520190           -0.013421
# 2021-12-31                -0.001079     1759.619952           -0.014813
#
#               Hogs Port  GF Cattle  GF Cattle Port
# Date
# 2020-04-15  1200.000000        NaN     1200.000000
# 2020-04-16  1161.008403   0.112914     1335.496431
# 2020-04-17  1175.798319  -0.001749     1333.160286
# 2020-04-20  1243.697479  -0.005841     1325.373134
# 2020-04-21  1423.193277  -0.085390     1212.199870
# ...                 ...        ...             ...
# 2021-12-27  2249.411765  -0.002901     1695.262816
# 2021-12-28  2221.848739   0.011943     1715.509409
# 2021-12-29  2254.117647   0.017098     1744.841012
# 2021-12-30  2223.865546   0.005653     1754.704737
# 2021-12-31  2190.924370   0.005621     1764.568462
#
# [434 rows x 10 columns]

# %%
agriculture_daily_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
agriculture_daily_returns_sliced = agriculture_daily_returns.iloc[:, [1,3,5,7,9]]
agriculture_daily_returns_sliced
# Out:
#              Wheat Port    Corn Port  FD Cattle Port    Hogs Port  \
# Date
# 2020-04-15  1200.000000  1200.000000     1200.000000  1200.000000
# 2020-04-16  1177.798335  1201.879405     1209.817894  1161.008403
# 2020-04-17  1185.013876  1211.276429     1199.049881  1175.798319
# 2020-04-20  1215.541166  1181.205951     1184.798100  1243.697479
# 2020-04-21  1218.316374  1162.411903     1160.411718  1423.193277
# ...                 ...          ...             ...          ...
# 2021-12-27  1785.013876  2310.728269     1739.350752  2249.411765
# 2021-12-28  1739.500463  2273.140172     1754.235946  2221.848739
# 2021-12-29  1748.936170  2275.959280     1765.954078  2254.117647
# 2021-12-30  1731.174838  2240.250587     1761.520190  2223.865546
# 2021-12-31  1711.193340  2229.913861     1759.619952  2190.924370
#
#             GF Cattle Port
# Date
# 2020-04-15     1200.000000
# 2020-04-16     1335.496431
# 2020-04-17     1333.160286
# 2020-04-20     1325.373134
# 2020-04-21     1212.199870
# ...                    ...
# 2021-12-27     1695.262816
# 2021-12-28     1715.509409
# 2021-12-29     1744.841012
# 2021-12-30     1754.704737
# 2021-12-31     1764.568462
#
# [434 rows x 5 columns]
